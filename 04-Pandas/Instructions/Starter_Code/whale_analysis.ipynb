# %% [markdown]
#  #  A Whale off the Port(folio)
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500.

# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
# 1. whale_returns.csv
# 2. algo_returns.csv
# 3. sp500_history.csv

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_returns_csv = Path("Resources/whale_returns.csv")
whale_df = pd.read_csv(whale_returns_csv, index_col="Date", parse_dates=True, infer_datetime_format=True)
whale_df.sort_index()
whale_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df = whale_df.dropna().copy()
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns_csv = Path("Resources/algo_returns.csv")
algo_df = pd.read_csv(algo_returns_csv, index_col="Date", parse_dates=True, infer_datetime_format=True)
algo_df.sort_index()
algo_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_df = algo_df.dropna().copy()
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P500 Historic Closing Prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_history_csv = Path("Resources/sp500_history.csv")
sp500_df = pd.read_csv(sp500_history_csv, index_col="Date", parse_dates=True, infer_datetime_format=True)
sp500_df.sort_index(inplace=True)
sp500_df.head()
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93

# %%
# Check Data Types
sp500_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_df['Close'] = sp500_df['Close'].str.replace('$', '').str.replace(',','')
sp500_df['Close'] = sp500_df['Close'].astype('float')
sp500_df.head()
# Out:
#               Close
# Date
# 2012-10-01  1444.49
# 2012-10-02  1445.75
# 2012-10-03  1450.99
# 2012-10-04  1461.40
# 2012-10-05  1460.93

# %%
# Calculate Daily Returns
sp500_df.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Drop nulls
daily_returns = sp500_df.pct_change() 
daily_returns.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
# Rename Column
daily_returns = daily_returns.dropna().copy()
daily_returns.isnull().sum()
daily_returns.head()
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Concatenate all DataFrames into a single DataFrame
daily_returns =daily_returns.rename(columns={'Close': 'S&P 500'})
daily_returns.head()
# Out:
#              S&P 500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance
#
# Calculate and Plot the daily returns and cumulative returns. Does any portfolio outperform the S&P 500?

# %%
# Plot daily returns
all_daily_returns = pd.concat([whale_df, algo_df,daily_returns], axis="columns", join="inner")
all_daily_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# ...                               ...                 ...
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-02                          NaN                     NaN -0.008158
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# ...                                 ...                     ...       ...
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
# 2019-04-23                     0.006472                0.013278  0.004969
#
#               Algo 2   S&P 500
# Date
# 2015-03-02  0.003200  0.006125
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196
# 2015-03-06 -0.011460 -0.014174
# ...              ...       ...
# 2019-04-16  0.002899  0.000509
# 2019-04-17 -0.005228 -0.002274
# 2019-04-18 -0.001229  0.001579
# 2019-04-22 -0.001936  0.001012
# 2019-04-23  0.009622  0.008841
#
# [1044 rows x 7 columns]

# %%
# Plot cumulative returns
all_daily_returns.plot(title="Daily Returns Across All Portfolios", figsize=(15,10), legend=True)

# %% [markdown]
# ## Risk
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %%
# Box plot to visually show risk
all_cumu_returns = (1 + all_daily_returns).cumprod() + 1
all_cumu_returns.plot(title="Cumulative ReturnsAcross All Portfolios", figsize=(15,10), legend=True)

# %%
# Daily Standard Deviations
# Calculate the standard deviation for each portfolio. 
# Which portfolios are riskier than the S&P 500?
all_daily_returns.plot.box(figsize=(20,10), legend=True)

# %%
# Determine which portfolios are riskier than the S&P 500
daily_devi = all_daily_returns.std()
daily_devi
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007621
# Algo 2                         0.008339
# S&P 500                        0.008551
# dtype: float64

# %%
# Calculate the annualized standard deviation (252 trading days)
SP500_std = all_daily_returns["S&P 500"].std()
all_daily_returns.std() > SP500_std
# Out:
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# S&P 500                        False
# dtype: bool

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Plot the rolling standard deviation of the various portfolios along with the rolling standard deviation of the S&P 500 (consider a 21 day window). Does the risk increase for each of the portfolios at the same time risk increases in the S&P?
# 2. Construct a correlation table for the algorithmic, whale, and S&P 500 returns. Which returns most closely mimic the S&P?
# 3. Choose one portfolio and plot a rolling beta between that portfolio's returns and S&P 500 returns. Does the portfolio seem sensitive to movements in the S&P 500?
# 4. An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the ewm with a 21 day half-life.

# %%
# Calculate and plot the rolling standard deviation for
# the S&P 500 and whale portfolios using a 21 trading day window
all_daily_returns.rolling(window=21).std().plot(title="21 Day Rolling Standard Deviation",figsize=( 24,10) ,legend=True)

# %%
# Construct a correlation table
correlation = all_daily_returns.corr()
correlation.style.background_gradient(cmap="inferno")
# Out:
# <style  type="text/css" >
#     #T_3ab11fa8_2ada_11eb_8dca_acde48001122row0_col0 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row0_col1 {
#             background-color:  #d94d3d;
#             color:  #000000;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row0_col2 {
#             background-color:  #b1325a;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row0_col3 {
#             background-color:  #eb6429;
#             color:  #000000;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row0_col4 {
#             background-color:  #3d0965;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row0_col5 {
#             background-color:  #fa9008;
#             color:  #000000;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row0_col6 {
#             background-color:  #fb9906;
#             color:  #000000;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row1_col0 {
#             background-color:  #cf4446;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row1_col1 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row1_col2 {
#             background-color:  #741a6e;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row1_col3 {
#             background-color:  #82206c;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row1_col4 {
#             background-color:  #210c4a;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row1_col5 {
#             background-color:  #cc4248;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row1_col6 {
#             background-color:  #ca404a;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row2_col0 {
#             background-color:  #801f6c;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row2_col1 {
#             background-color:  #4c0c6b;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row2_col2 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row2_col3 {
#             background-color:  #3b0964;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row2_col4 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row2_col5 {
#             background-color:  #6d186e;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row2_col6 {
#             background-color:  #b3325a;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row3_col0 {
#             background-color:  #e75e2e;
#             color:  #000000;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row3_col1 {
#             background-color:  #8a226a;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row3_col2 {
#             background-color:  #6f196e;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row3_col3 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row3_col4 {
#             background-color:  #2d0b59;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row3_col5 {
#             background-color:  #d04545;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row3_col6 {
#             background-color:  #eb6429;
#             color:  #000000;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row4_col0 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row4_col1 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row4_col2 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row4_col3 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row4_col4 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row4_col5 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row4_col6 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row5_col0 {
#             background-color:  #f98b0b;
#             color:  #000000;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row5_col1 {
#             background-color:  #d04545;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row5_col2 {
#             background-color:  #982766;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row5_col3 {
#             background-color:  #d04545;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row5_col4 {
#             background-color:  #290b55;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row5_col5 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row5_col6 {
#             background-color:  #fca60c;
#             color:  #000000;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row6_col0 {
#             background-color:  #fa9207;
#             color:  #000000;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row6_col1 {
#             background-color:  #cc4248;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row6_col2 {
#             background-color:  #cc4248;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row6_col3 {
#             background-color:  #ea632a;
#             color:  #000000;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row6_col4 {
#             background-color:  #240c4f;
#             color:  #f1f1f1;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row6_col5 {
#             background-color:  #fca60c;
#             color:  #000000;
#         }    #T_3ab11fa8_2ada_11eb_8dca_acde48001122row6_col6 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }</style><table id="T_3ab11fa8_2ada_11eb_8dca_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SOROS FUND MANAGEMENT LLC</th>        <th class="col_heading level0 col1" >PAULSON & CO.INC. </th>        <th class="col_heading level0 col2" >TIGER GLOBAL MANAGEMENT LLC</th>        <th class="col_heading level0 col3" >BERKSHIRE HATHAWAY INC</th>        <th class="col_heading level0 col4" >Algo 1</th>        <th class="col_heading level0 col5" >Algo 2</th>        <th class="col_heading level0 col6" >S&P 500</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3ab11fa8_2ada_11eb_8dca_acde48001122level0_row0" class="row_heading level0 row0" >SOROS FUND MANAGEMENT LLC</th>
#                         <td id="T_3ab11fa8_2ada_11eb_8dca_acde48001122row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_3ab11fa8_2ada_11eb_8dca_acde48001122row0_col1" class="data row0 col1" >0.699914</td>
#                         <td id="T_3ab11fa8_2ada_11eb_8dca_acde48001122row0_col2" class="data row0 col2" >0.561243</td>
#                         <td id="T_3ab11fa8_2ada_11eb_8dca_acde48001122row0_col3" class="data row0 col3" >0.754360</td>
#                         <td id="T_3ab11fa8_2ada_11eb_8dca_acde48001122row0_col4" class="data row0 col4" >0.321211</td>
#                         <td id="T_3ab11fa8_2ada_11eb_8dca_acde48001122row0_col5" class="data r

# %%
# Calculate Beta for a single portfolio compared to the total market (S&P 500)
# (Your graph may differ, dependent upon which portfolio you are comparing)
portfolio_cov = all_daily_returns['TIGER GLOBAL MANAGEMENT LLC'].rolling(window=30).cov(all_daily_returns["S&P 500"])
portfolio_var = all_daily_returns["S&P 500"].rolling(30).var()
beta_portfolio = portfolio_cov/portfolio_var
beta_portfolio.plot(figsize= (25,10), title = "TIGER GLOBAL MANAGEMENT LLC Beta")

# %%
# Calculate a rolling window using the exponentially weighted moving average. 
all_daily_returns.ewm(halflife =21).std().plot(figsize=(25,10), title = "Exponentially Weighthed Average")

# %% [markdown]
# ---

# %% [markdown]
# ## Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. (After all, if you could invest in one of two portfolios, each offered the same 10% return, yet one offered lower risk, you'd take that one, right?)
#
# 1. Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot.
# 2. Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.

# %%
# Calculate annualized Sharpe Ratios
sharpe_ratio = (all_daily_returns.mean() * 252) / (all_daily_returns.std() * np.sqrt(252))
sharpe_ratio
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.360829
# Algo 2                         0.506929
# S&P 500                        0.658706
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratio.plot(kind='bar')

# %% [markdown]
# On the basis of this performance metric, do our algo strategies outperform both 'the market' and the whales? Type your answer here:

# %% [markdown]
# ---

# %% [markdown]
# # Portfolio Returns
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Visit [Google Sheets](https://docs.google.com/spreadsheets/) and use the in-built Google Finance function to choose 3-5 stocks for your own portfolio.
# 2. Download the data as CSV files and calculate the portfolio returns.
# 3. Calculate the returns for each stock.
# 4. Using those returns, calculate the weighted returns for your entire portfolio assuming an equal number of shares for each stock.
# 5. Add your portfolio returns to the DataFrame with the other portfolios and rerun the analysis. How does your portfolio fair?
#
#
# ## Your analysis should include the following:
#
# - Using all portfolios:
#  - The annualized standard deviation (252 trading days) for all portfolios.
#  - The plotted rolling standard deviation using a 21 trading day window for all portfolios.
#  - The calculated annualized Sharpe Ratios and the accompanying bar plot visualization.
#  - A correlation table.
# - Using your custom portfolio and one other of your choosing:
#  - The plotted beta.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Read the first stock
cost_csv = Path("Resources/cost_historical.csv")
cost_df = pd.read_csv(cost_csv)
cost_df.set_index(pd.to_datetime(cost_df['Trade DATE'], infer_datetime_format = True), inplace = True)
cost_df.drop(columns = ['Trade DATE','Symbol'], inplace = True)
cost_df.rename(columns = {'NOCP':'COST'}, inplace=True)
cost_df.head()
# Out:
#               COST
# Trade DATE
# 2019-05-09  243.47
# 2019-05-08  241.34
# 2019-05-07  240.18
# 2019-05-06  244.23
# 2019-05-03  244.62

# %%
# Read the second stock
google_csv = Path("Resources/goog_historical.csv")
google_df= pd.read_csv(google_csv)
google_df.set_index(pd.to_datetime(google_df['Trade DATE'], infer_datetime_format = True), inplace = True)
google_df.drop(columns = ['Trade DATE','Symbol'], inplace = True)
google_df.rename(columns = {'NOCP':'GOOG'}, inplace=True)
google_df.head()
# Out:
#                GOOG
# Trade DATE
# 2019-05-09  1162.38
# 2019-05-08  1166.27
# 2019-05-07  1174.10
# 2019-05-06  1189.39
# 2019-05-03  1185.40

# %%
# Read the third stock
apple_csv = Path("Resources/aapl_historical.csv")
apple_df = pd.read_csv(apple_csv)
apple_df.set_index(pd.to_datetime(apple_df['Trade DATE'], infer_datetime_format = True), inplace = True)
apple_df.drop(columns = ['Trade DATE','Symbol'], inplace = True)
apple_df.rename(columns = {'NOCP':'AAPL'}, inplace=True)
apple_df.head()
# Out:
#               AAPL
# Trade DATE
# 2019-05-09  200.72
# 2019-05-08  202.90
# 2019-05-07  202.86
# 2019-05-06  208.48
# 2019-05-03  211.75

# %%
# Concatenate all stocks into a single DataFrame
concatenate_df = pd.concat([apple_df,cost_df,google_df], axis="columns", join="inner")
concatenate_df
# Out:
#               AAPL    COST     GOOG
# Trade DATE
# 2019-05-09  200.72  243.47  1162.38
# 2019-05-08  202.90  241.34  1166.27
# 2019-05-07  202.86  240.18  1174.10
# 2019-05-06  208.48  244.23  1189.39
# 2019-05-03  211.75  244.62  1185.40
# ...            ...     ...      ...
# 2018-05-17  186.99  199.60  1078.59
# 2018-05-16  188.18  198.71  1081.77
# 2018-05-15  186.44  195.48  1079.23
# 2018-05-14  188.15  195.88  1100.20
# 2018-05-11  188.59  195.76  1098.26
#
# [250 rows x 3 columns]

# %%
# Reset the index
concatenate_df.reset_index()
# Out:
#     Trade DATE    AAPL    COST     GOOG
# 0   2019-05-09  200.72  243.47  1162.38
# 1   2019-05-08  202.90  241.34  1166.27
# 2   2019-05-07  202.86  240.18  1174.10
# 3   2019-05-06  208.48  244.23  1189.39
# 4   2019-05-03  211.75  244.62  1185.40
# ..         ...     ...     ...      ...
# 245 2018-05-17  186.99  199.60  1078.59
# 246 2018-05-16  188.18  198.71  1081.77
# 247 2018-05-15  186.44  195.48  1079.23
# 248 2018-05-14  188.15  195.88  1100.20
# 249 2018-05-11  188.59  195.76  1098.26
#
# [250 rows x 4 columns]

# %%
# Pivot so that each column of prices represents a unique symbol
custom_pivot = pd.pivot_table(concatenate_df, index="Trade DATE", values = ['AAPL','GOOG','COST'])
custom_pivot
# Out:
#               AAPL    COST     GOOG
# Trade DATE
# 2018-05-11  188.59  195.76  1098.26
# 2018-05-14  188.15  195.88  1100.20
# 2018-05-15  186.44  195.48  1079.23
# 2018-05-16  188.18  198.71  1081.77
# 2018-05-17  186.99  199.60  1078.59
# ...            ...     ...      ...
# 2019-05-03  211.75  244.62  1185.40
# 2019-05-06  208.48  244.23  1189.39
# 2019-05-07  202.86  240.18  1174.10
# 2019-05-08  202.90  241.34  1166.27
# 2019-05-09  200.72  243.47  1162.38
#
# [250 rows x 3 columns]

# %%
# Drop Nulls
concatenate_df= concatenate_df.dropna().copy()
concatenate_df.isnull().sum()
# Out:
# AAPL    0
# COST    0
# GOOG    0
# dtype: int64

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Calculate weighted portfolio returns
weights = [1/3, 1/3, 1/3]
portfolio_returns = concatenate_df.pct_change().dot(weights)
portfolio_returns.dropna(inplace=True)
portfolio_returns.head()
# Out:
# Trade DATE
# 2019-05-08    0.001820
# 2019-05-07    0.000570
# 2019-05-06    0.019196
# 2019-05-03    0.004642
# 2019-05-02   -0.013131
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Add your "Custom" portfolio to the larger dataframe of fund returns
all_daily_returns["Custom"] = portfolio_returns
all_daily_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# ...                               ...                 ...
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-02                          NaN                     NaN -0.008158
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# ...                                 ...                     ...       ...
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
# 2019-04-23                     0.006472                0.013278  0.004969
#
#               Algo 2   S&P 500    Custom
# Date
# 2015-03-02  0.003200  0.006125       NaN
# 2015-03-03 -0.000949 -0.004539       NaN
# 2015-03-04  0.002416 -0.004389       NaN
# 2015-03-05  0.004323  0.001196       NaN
# 2015-03-06 -0.011460 -0.014174       NaN
# ...              ...       ...       ...
# 2019-04-16  0.002899  0.000509 -0.009149
# 2019-04-17 -0.005228 -0.002274 -0.001541
# 2019-04-18 -0.001229  0.001579 -0.001148
# 2019-04-22 -0.001936  0.001012 -0.011812
# 2019-04-23  0.009622  0.008841 -0.000415
#
# [1044 rows x 8 columns]

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
all_daily_returns.dropna(inplace = True)

# %% [markdown]
# ## Re-run the performance and risk analysis with your portfolio to see how it compares to the others

# %%
# Risk
all_daily_returns.plot.box(figsize=(25,10), legend=True)

# %%
# Rolling
all_daily_returns.rolling(window=21).std().plot(title="21 Day Rolling Standard Deviation",figsize=( 24,10) ,legend=True)

# %%
# Annualized Sharpe Ratios
sharpe_ratio = (all_daily_returns.mean() * 252) / (all_daily_returns.std() * np.sqrt(252))
sharpe_ratio
# Out:
# SOROS FUND MANAGEMENT LLC      0.395449
# PAULSON & CO.INC.              0.267115
# TIGER GLOBAL MANAGEMENT LLC   -1.019946
# BERKSHIRE HATHAWAY INC         0.141691
# Algo 1                         2.034208
# Algo 2                         0.082577
# S&P 500                        0.595486
# Custom                        -0.614330
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratio.plot(kind='bar')

# %%
# Create a correlation analysis
correlation = all_daily_returns.corr()
correlation.style.background_gradient(cmap="inferno")
# Out:
# <style  type="text/css" >
#     #T_e3acc68e_2ada_11eb_8dca_acde48001122row0_col0 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row0_col1 {
#             background-color:  #fc9f07;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row0_col2 {
#             background-color:  #ab2f5e;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row0_col3 {
#             background-color:  #fcac11;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row0_col4 {
#             background-color:  #65156e;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row0_col5 {
#             background-color:  #fac228;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row0_col6 {
#             background-color:  #fac62d;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row0_col7 {
#             background-color:  #09061f;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row1_col0 {
#             background-color:  #fb9b06;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row1_col1 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row1_col2 {
#             background-color:  #ae305c;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row1_col3 {
#             background-color:  #e9612b;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row1_col4 {
#             background-color:  #6f196e;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row1_col5 {
#             background-color:  #fb9906;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row1_col6 {
#             background-color:  #f98c0a;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row1_col7 {
#             background-color:  #02010a;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row2_col0 {
#             background-color:  #a52c60;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row2_col1 {
#             background-color:  #b0315b;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row2_col2 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row2_col3 {
#             background-color:  #741a6e;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row2_col4 {
#             background-color:  #060419;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row2_col5 {
#             background-color:  #8d2369;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row2_col6 {
#             background-color:  #a52c60;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row2_col7 {
#             background-color:  #030210;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row3_col0 {
#             background-color:  #fca60c;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row3_col1 {
#             background-color:  #e8602d;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row3_col2 {
#             background-color:  #6a176e;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row3_col3 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row3_col4 {
#             background-color:  #61136e;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row3_col5 {
#             background-color:  #fb9906;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row3_col6 {
#             background-color:  #fbba1f;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row3_col7 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row4_col0 {
#             background-color:  #69166e;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row4_col1 {
#             background-color:  #7d1e6d;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row4_col2 {
#             background-color:  #10092d;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row4_col3 {
#             background-color:  #741a6e;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row4_col4 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row4_col5 {
#             background-color:  #7a1d6d;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row4_col6 {
#             background-color:  #510e6c;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row4_col7 {
#             background-color:  #0c0826;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row5_col0 {
#             background-color:  #fac026;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row5_col1 {
#             background-color:  #fb9b06;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row5_col2 {
#             background-color:  #8f2469;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row5_col3 {
#             background-color:  #fb9b06;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row5_col4 {
#             background-color:  #71196e;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row5_col5 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row5_col6 {
#             background-color:  #fac62d;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row5_col7 {
#             background-color:  #040312;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row6_col0 {
#             background-color:  #f9c72f;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row6_col1 {
#             background-color:  #fa9207;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row6_col2 {
#             background-color:  #ad305d;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row6_col3 {
#             background-color:  #fbbe23;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row6_col4 {
#             background-color:  #4f0d6c;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row6_col5 {
#             background-color:  #f9c72f;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row6_col6 {
#             background-color:  #fcffa4;
#             color:  #000000;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row6_col7 {
#             background-color:  #0b0724;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row7_col0 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row7_col1 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row7_col2 {
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }    #T_e3acc68e_2ada_11eb_8dca_acde48001122row7_col3 {
#             background-color:  #000004;
#             color:  #f1f1f1;

# %%
# Beta
portfolio_cov = all_daily_returns['Custom'].rolling(window=30).cov(all_daily_returns["S&P 500"])
portfolio_var = all_daily_returns["S&P 500"].rolling(30).var()
beta = portfolio_cov / portfolio_var
beta.plot(figsize=(20,10), title = " Custom Portfolio Beta")
